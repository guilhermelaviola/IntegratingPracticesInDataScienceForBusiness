# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/IntegratingPracticeInDataScienceForBusiness/blob/main/Class02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scraping**
#
# First, we will import the necessary libraries, such as requests to make HTTP requests and BeautifulSoup to parse the HTML. Then, we define the URL of the website from which the data will be extracted. Remember that the website must allow this type of activity.

# %%
# Importing all the necessary libraries:
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://sempreinter.com/latest-news/'
response = requests.get(url)
html_content = response.content
soup = BeautifulSoup(html_content, 'html.parser')

# %%
headlines = soup.find_all(class_= 'main_article')

for headline in headlines:
  print(headline.get_text())
# Out:
# Como 0-2 – Inter Milan INTERViews Podcast Ep. 147: “Where The Serie A Season Went Wrong For Inter”
#
#
#
#
# May 27, 2025 19:48
#
#
#
#
# This is the INTERViews podcast, the official SempreInter.com podcast, discussing all things Nerazzurri, today focusing on Como 0-2 Inter Milan as well as Serie A…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Dinamo Zagreb Loanee Admits He “Didn’t Think Twice” When Inter Milan Approached Him
#
#
#
#
# May 27, 2025 17:56
#
#
#
#
# Talented midfielder Petar Sucic will complete his transfer from Dinamo Zagreb to Inter Milan in less than a week. During his recent interview via FCInterNews,…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Report – Inter Milan Set To Announce Arrival Of Marseille Winger After Juventus & Nottingham Forest Fail To Hijack Deal
#
#
#
#
# May 27, 2025 17:17
#
#
#
#
# ( 1 )
#
#
#
#
#
# Luis Henrique is on the verge of joining Inter Milan from Marseille despite Juventus’ late attempt to hijack the deal. Per Sport.fr via FCInterNews, Nottingham…
#
#
#
#
#
#
#
# Latest Inter Videos
#
#
#
#
#
#
#
#
#
#
#
#
# Ex Inter Milan & Belgium Midfielder Recalls Bizzare Incident During His San Siro Stint: “Fan Slapped Me After A Match Went Badly”
#
#
#
#
# May 27, 2025 15:48
#
#
#
#
# Former Inter Milan midfielder Radja Nainggolan revealed a shocking incident during his turbulent three-year stint at San Siro. During an interview for the TV show…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Venezia Sporting Director Confirms: “We Will Activate Option” To Sign Inter Milan Owned Goalkeeper This Summer
#
#
#
#
# May 27, 2025 14:31
#
#
#
#
# Venezia sporting director Filippo Antonelli confirms the Ligurian outfit will activate a buyout clause to sign Inter Milan loanee Filip Stankovic. During his recent interview,…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Backup Plan – Inter Milan Consider Two Managers In Case Simone Inzaghi Waves Goodbye This Summer
#
#
#
#
# May 27, 2025 14:06
#
#
#
#
# ( 7 )
#
#
#
#
#
# Massimiliano Allegri and Cesc Fabregas have emerged as potential candidates to replace Simone Inzaghi at Inter Milan. Per Corriere dello Sport via FCInterNews, the ex-Juventus…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Turkey Captain Urges Inter Milan To “Put Their Heart” Into Champions League Final
#
#
#
#
# May 27, 2025 13:42
#
#
#
#
# Inter Milan star Hakan Calhanoglu highlighted the need for the right mindset heading into Saturday’s Champions League final. Speaking to Sky Sport via FCInterNews, the…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Inter Milan President Hits Out: “I’m In Favor Of Football Competency But Not Every Club Has It”
#
#
#
#
# May 27, 2025 13:23
#
#
#
#
# Inter Milan president Beppe Marotta talked to the press before Saturday’s Champions League final against PSG. Speaking to RSI via FCInterNews, the former Juventus chief…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Simone Inzaghi Wants Guarantees On 3 Fonts Before Committing To New Inter Milan Contract
#
#
#
#
# May 27, 2025 13:04
#
#
#
#
# ( 6 )
#
#
#
#
#
# Simone Inzaghi and Inter Milan will soon meet at the negotiating table to discuss the in-demand manager’s contract renewal. Per La Repubblica via FCInterNews, the…
#
#
#
#
#
#
#
#
# 1
# 2
# …
# 13,578
# Next »
